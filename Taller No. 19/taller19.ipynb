# %% [markdown]
# ##**Taller No. 19** SLIT – Respuesta impulso.

# %% [markdown]
# ###**1.** Se tiene un SLIT con la siguiente respuesta impulso:
#
# $$h( t) \ =\ u( t+1) -u( t-1)$$
#
# ### Hallar la relación entrada salida

# %% [markdown]
# $$y( t) =x( t) *h( t) =\int _{-\infty }^{\infty } x( \tau ) \cdot [ u( t+1-\tau ) -u( t-1-\tau )] d\tau =\int _{t-1}^{t+1} x( \tau ) d\tau $$

# %% [markdown]
# ###**3.** A partir de la respuesta impulso de los siguientes SLIT mostrados en la figura.
#
# ![taller19-3-1.png](data:image/png;base64,...)
#
# ###Indicar cuáles de las siguientes propiedades cumple o no cada SLIT: memoria, causalidad, estabilidad

# %% [markdown]
# ####**a.**
#
# *   Memoria: Sistema con memoria
# *   Causalidad: Sistema causal
# *   Estabilidad: Sistema estable

# %% [markdown]
# ####**b.**
#
# *   Memoria: Sistema sin memoria
# *   Causalidad: Sistema causal
# *   Estabilidad: Sistema estable

# %% [markdown]
# ####**c.**
#
# *   Memoria: Sistema con memoria
# *   Causalidad: Sistema no causal
# *   Estabilidad: Sistema estable

# %% [markdown]
# ####**d.**
#
# *   Memoria: Sistema con memoria
# *   Causalidad: Sistema no causal
# *   Estabilidad: Sistema estable

# %% [markdown]
# ###**5.** Demuestre o refute las siguientes dos afirmaciones:

# %% [markdown]
# ####**a.** Si la señal de entrada a un SLIT $\displaystyle x( t) \ =\ 0$, en el intervalo $\displaystyle t< t_{1}$ y la respuesta impulso de este SLIT es $\displaystyle h( t) =0$, para $\displaystyle t< t_{2}$, entonces su señal de salida será:
#
#
# \begin{equation*}
# y( t) =x( t) *h( t) =0,\ para\ t< t_{1} +t_{2}
# \end{equation*}

# %% [markdown]
# Al observar la convolución:
#
# ![taller19-5-1.png](data:image/png;base64,...)
#
# La salida deja de ser cero cuando:
#
#  \begin{array}{l}
# t-t_{2} =t_{1}\\
# t=t_{1} +t_{2}
# \end{array}

# %% [markdown]
# ###**b** Si $\displaystyle y( t) =x( t) *h( t) =0$, entonces se puede afirmar que:
#
#
# \begin{equation*}
# y( t-1) =x( t-1) *h( t-1) =0
# \end{equation*}

# %% [markdown]
# ![taller19-5-2.png](data:image/png;base64,...)

# %% [markdown]
# ###**6.** En la figura se muestra la señal de entrada $x(t)$  a un SLIT y su correspondiente señal de salida $y(t)$:
#
# ![taller19-6-1.png](data:image/png;base64,...)
#
# ### Seleccione la respuesta adecuada para la respuesta impulso del sistema:
#
# ![taller19-6-2.png](data:image/png;base64,...)

# %% [markdown]
# Ninguna de las anteriores

# %% [markdown]
# ***Juan Sebastián Bravo Santacruz***
#
# ***Jairo Alberto Hurtado Londoño***
#
# Bogotá, 2021
#
# ![tiara_javeriana.png](data:image/png;base64,...)
