# %% [markdown]
# ##**Taller No. 20** SLIT - Convolución

# %% [markdown]
# ###**1.** Sea $x(t)$ la entrada a un SLIT con respuesta impulso $h(t)$, tal y como se muestra en la figura:
#
# ![taller20-1-1.png](data:image/png;base64,...)
#
# ### Hallar la salida $y(t)$ del sistema

# %% [markdown]
# ![taller20-1-2.png](data:image/png;base64,...)

# %% [markdown]
# ###**2.** Sea $x(t)$ la entrada a un SLIT como se muestra en la figura:
#
# ![taller20-2-1.png](data:image/png;base64,...)
#
# ### Con respuesta impulso $h(t)$ tal como se muestra en la figura:
#
# ![taller20-2-2.png](data:image/png;base64,...)
#
# ### Hallar la salida $y(t)$ del sistema

# %% [markdown]
# ![taller20-2-3.png](data:image/png;base64,...)

# %% [markdown]
# ###**3.** Sea $x(t)$ la señal mostrada en la figura:
#
# ![taller20-3-1.png](data:image/png;base64,...)
#
# ### Graficar $z(t) =x(t)*x(t)$

# %% [markdown]
# ![taller20-3-2.png](data:image/png;base64,...)

# %% [markdown]
# ###**4.** Sea $x(t)$ la entrada a un SLIT con respuesta impulso $h(t)$, tal y como se muestra en la figura:
#
# ![taller20-4-1.png](data:image/png;base64,...)
#
# ### Hallar la salida $y(t)$ del sistema

# %% [markdown]
# ![taller20-4-2.png](data:image/png;base64,...)

# %% [markdown]
# ###**6.** Sea $\displaystyle x( t) =u( t)$ y $\displaystyle h( t) =u( t) \cdotp e^{-\frac{t}{2}}$, la señal de entrada y la respuesta impulso de un SLIT.
#
# ###Hallar la ecuación que describe $\displaystyle y( t) =x( t) *h( t)$.

# %% [markdown]
# $$ \begin{array}{l}
# y( t) =\int _{-\infty }^{\infty } u( \tau ) \cdotp e^{-\frac{\tau }{2}} \cdotp u( t-\tau ) \ d\tau \\
# \\
# y( t) \ =\ \int _{0}^{t} e^{-\frac{\tau }{2}} \ d\tau =-2e^{-\frac{t}{2}} +2
# \end{array}$$

# %% [markdown]
# ***Juan Sebastián Bravo Santacruz***
#
# ***Jairo Alberto Hurtado Londoño***
#
# Bogotá, 2021
#
# ![tiara_javeriana.png](data:image/png;base64,...)
