# %% [markdown]
# ##**Taller No. 23** Transformada de Fourier y propiedades

# %% [markdown]
# ###**1.** Hallar la ecuación y realizar la gráfica (indicando amplitudes y frecuencias relevantes) de la **transformada de Fourier** de las siguientes señales

# %% [markdown]
# ####**a.** $$x_{1}( t) =4\delta ( t)$$

# %% [markdown]
# $$X_{1}( j\omega ) =4$$

# %%
import matplotlib.pyplot as plt
import numpy as np

# Vector omega
w = np.linspace(-4,4,1000)

# Calculo de señal
sig = []
for x in w:
    sig.append(4)

# Gráfica de la señal
plt.plot(w, sig)
plt.xlabel(r'$\omega$')
plt.ylabel(r'$X_1(j\omega)$')
plt.title(r'$X_1(j\omega)$')
plt.grid(True)
plt.show()

# %% [markdown]
# ####**b.** $$x_{2}( t) =u( t+2\pi ) -u( t-2\pi )$$

# %% [markdown]
# $$X_{2}( j\omega ) =2\cdot 2\pi \cdot sinc( 2\pi \cdot \omega ) =4\pi \cdot sinc( 2\pi \cdot \omega )$$

# %%
import matplotlib.pyplot as plt
import numpy as np

# Vector omega
w = np.linspace(-1,1,1000)

# Calculo de señal
sig = []
for x in w:
    sig.append(4*np.pi*np.sinc(2*np.pi*x))

# Gráfica de la señal
plt.plot(w, sig)
plt.xlabel(r'$\omega$')
plt.ylabel(r'$X_2(j\omega)$')
plt.title(r'$X_2(j\omega)$')
plt.grid(True)
plt.show()

# %% [markdown]
# ####**c.**
#
# ![taller23-1-1.png](data:image/png;base64,...)

# %% [markdown]
# $$X_{3}( j\omega ) =4\cdot 2\cdot 5\cdot sinc( 5\cdot \omega ) =40\cdot sinc( 5\cdot \omega )$$

# %%
import matplotlib.pyplot as plt
import numpy as np

# Vector omega
w = np.linspace(-1,1,1000)

# Calculo de señal
sig = []
for x in w:
    sig.append(40*np.sinc(5*x))

# Gráfica de la señal
plt.plot(w, sig)
plt.xlabel(r'$\omega$')
plt.ylabel(r'$X_3(j\omega)$')
plt.title(r'$X_3(j\omega)$')
plt.grid(True)
plt.show()

# %% [markdown]
# ###**2.** Hallar la ecuación y realizar la gráfica (indicando amplitudes y tiempos relevantes) de la **transformada inversa de Fourier** de las siguientes señales

# %% [markdown]
# ####**a.** $$X_{4}( jw) =4\delta ( \omega )$$

# %% [markdown]
# $$x_{4}( t) =\frac{2}{\pi } \cdot e^{j0t} =\frac{2}{\pi }$$

# %%
import matplotlib.pyplot as plt
import numpy as np

# Vector tiempo
t = np.linspace(-4,4,1000)

# Calculo de señal
sig = []
for x in t:
    sig.append(2/np.pi)

# Gráfica de la señal
plt.plot(t, sig)
plt.xlabel(r'$t$')
plt.ylabel(r'$x_4(t)$')
plt.title(r'$x_4(t)$')
plt.grid(True)
plt.show()

# %% [markdown]
# ####**b.** $$X_{5}( jw) =u( \omega +2\pi ) -u( \omega -2\pi )$$

# %% [markdown]
# $$x_{5}( t) =\frac{1}{2\pi } \cdot 2\cdot 2\pi \cdot sinc( 2\pi \cdot t) =2\cdot sinc( 2\pi \cdot t)$$

# %%
import matplotlib.pyplot as plt
import numpy as np

# Vector tiempo
t = np.linspace(-1,1,1000)

# Calculo de señal
sig = []
for x in t:
    sig.append(2*np.sinc(2*np.pi*x))

# Gráfica de la señal
plt.plot(t, sig)
plt.xlabel(r'$t$')
plt.ylabel(r'$x_5(t)$')
plt.title(r'$x_5(t)$')
plt.grid(True)
plt.show()

# %% [markdown]
# ####**c.**
#
# ![taller23-2-1.png](data:image/png;base64,...)

# %% [markdown]
# $$x_{6}( t) =5\cdot 2\cdot 2\cdot sinc( 2\cdot t) =20\cdot sinc( 2\cdot t)$$

# %%
import matplotlib.pyplot as plt
import numpy as np

# Vector tiempo
t = np.linspace(-4,4,1000)

# Calculo de señal
sig = []
for x in t:
    sig.append(20*np.sinc(2*x))

# Gráfica de la señal
plt.plot(t, sig)
plt.xlabel(r'$t$')
plt.ylabel(r'$x_6(t)$')
plt.title(r'$x_6(t)$')
plt.grid(True)
plt.show()

# %% [markdown]
# ###**3.** Graficar la **magnitud de la transformada de Fourier** (indicando amplitudes y frecuencias relevantes) de las siguientes señales

# %% [markdown]
# ####**a.** $$y_{1}( t) =4\cdot \delta ( t-\pi )$$

# %% [markdown]
# $$Y_{1}( j\omega ) =4\cdot e^{-j\omega \pi }$$

# %%
import matplotlib.pyplot as plt
import numpy as np

# Vector omega
w = np.linspace(-4,4,1000)

# Calculo de señal
sig = []
for x in w:
    sig.append(4)

# Gráfica de la señal
plt.plot(w, sig)
plt.xlabel(r'$\omega$')
plt.ylabel(r'$Y_1(j\omega)$')
plt.title(r'$Y_1(j\omega)$')
plt.grid(True)
plt.show()

# %% [markdown]
# ####**c.** $$y_{3}( t) =e^{-3t} \cdot u( t)$$

# %% [markdown]
# $$Y_{3}( j\omega ) =\frac{1}{3+j\omega }$$

# %%
import matplotlib.pyplot as plt
import numpy as np

# Vector omega
w = np.linspace(-10,10,1000)

# Calculo de señal
sig = []
for x in w:
    sig.append(np.absolute(1/(3+x*1j)))

# Gráfica de la señal
plt.plot(w, sig)
plt.xlabel(r'$\omega$')
plt.ylabel(r'$Y_3(j\omega)$')
plt.title(r'$Y_3(j\omega)$')
plt.grid(True)
plt.show()

# %% [markdown]
# ####**d.**
#
# ![taller23-3-1.png](data:image/png;base64,...)

# %% [markdown]
# $$Y_{4}( j\omega ) =4\cdot 2\cdot 5\cdot sinc( 5\cdot \omega ) \cdot e^{-j\omega 5} =40\cdot sinc( 5\cdot \omega ) \cdot e^{-j\omega 5}$$

# %%
import matplotlib.pyplot as plt
import numpy as np

# Vector omega
w = np.linspace(-1,1,1000)

# Calculo de señal
sig = []
for x in w:
    sig.append(40*np.sinc(5*x))

# Gráfica de la señal
plt.plot(w, sig)
plt.xlabel(r'$\omega$')
plt.ylabel(r'$Y_4(j\omega)$')
plt.title(r'$Y_4(j\omega)$')
plt.grid(True)
plt.show()

# %% [markdown]
# ###**4.** Graficar la **parte real de la transformada inversa de Fourier** gráfica (indicando amplitudes y tiempos relevantes) de la de las siguientes señales

# %% [markdown]
# ####**a.** $$Y_{5}( j\omega ) =4\cdot \delta ( \omega -\pi )$$

# %% [markdown]
# $$y_{5}( t) =\frac{2}{\pi } \cdot e^{j\pi t}$$

# %%
import matplotlib.pyplot as plt
import numpy as np

# Vector tiempo
t = np.linspace(-4,4,1000)

# Calculo de señal
sig = []
for x in t:
    sig.append(2/np.pi*np.cos(np.pi*x))

# Gráfica de la señal
plt.plot(t, sig)
plt.xlabel(r'$t$')
plt.ylabel(r'$y_5(t)$')
plt.title(r'$y_5(t)$')
plt.grid(True)
plt.show()

# %% [markdown]
# ####**c.** $$Y_{7}( jw) =u( \omega +2\pi ) -u( \omega -2\pi )$$

# %% [markdown]
# $$y_{7}( t) =\frac{1}{2\pi } \cdot 2\cdot 2\pi \cdot sinc( 2\pi \cdot t) =2\cdot sinc( 2\pi \cdot t)$$

# %%
import matplotlib.pyplot as plt
import numpy as np

# Vector tiempo
t = np.linspace(-1,1,1000)

# Calculo de señal
sig = []
for x in t:
    sig.append(2*np.sinc(2*np.pi*x))

# Gráfica de la señal
plt.plot(t, sig)
plt.xlabel(r'$t$')
plt.ylabel(r'$y_7(t)$')
plt.title(r'$y_7(t)$')
plt.grid(True)
plt.show()

# %% [markdown]
# ####**d.** $$Y_{8}( j\omega ) =2e^{j4\pi \omega }$$

# %% [markdown]
# $$y_{8}( t) =2\cdot \delta ( t+4\pi )$$

# %%
import matplotlib.pyplot as plt
import numpy as np

# Vector tiempo
t = np.linspace(-15,15,1000000)

def dirac_delta(t, a, b, t0, c):
  """
  Función que crea señal ax(bt - t0) + c 
  Toma como parametros un vector de tiempo(t) y a, b, t0 y c
  Retorna una pareja de tiempo y amplitud
  """
  # Entre más pequeño sea delta, mejor es la representación del impulso
  delta = 1/1000
  amp = []
  
  # Crea funcion dirac_delta(t)
  for x in t:
    if (x >= -delta/2) and (x <= delta/2):
      amp.append(1/delta)
    else:
      amp.append(0)

  # Desplazamiento y escalado en tiempo
  t = [(x-t0)/b for x in t]

  # Desplazamiento en eje vertical y escalado en amplitud
  amp = [(i*a)+c for i in amp]

  return (t, amp)

def integral(t, amp):
  """
  Función que calcula la integral de una señal
  Toma como parametros una pareja de (tiempo, amplitud)
  Retorna el resultado de la integral
  """
  dt = (max(t)- min(t))/len(t)
  area = 0

  for a in amp:
    area += dt*a

  return area

# Define la señal
t, sig = dirac_delta(t, 2, 1, 4*np.pi, 0)

# Imprime el area bajo la curva de la señal
print(f"El área bajo la curva de la señal es: {integral(t, sig)}")

# Gráfica de la señal
plt.plot(t,sig)
plt.xlabel(r'$t$')
plt.ylabel(r'$y_8(t)$')
plt.title(r'$y_8(t)$')
plt.grid(True)
plt.show()
# Out:
# El área bajo la curva de la señal es: 2.0400000000000014

# %% [markdown]
# ###**5.** Hallar la ecuación y realizar la gráfica (indicando amplitudes y frecuencias relevantes) de la transformada de Fourier de las siguientes señales periódicas:

# %% [markdown]
# ####**a.** $$x_{7}( t) =2\cdot e^{j4\pi t}$$

# %% [markdown]
# $$X_{7}( j\omega ) =2\cdot 2\pi \cdot \delta ( \omega -4\pi ) =4\pi \cdot \delta ( \omega -4\pi )$$

# %% [markdown]
# ####**b.** $$x_{8}( t) =3\cos( 2\pi \cdot 1000\cdot t)$$

# %% [markdown]
# $$X_{8}( j\omega ) =4\cdot \pi [ \delta ( \omega +2000\pi ) +\delta ( \omega -2000\pi )]$$

# %% [markdown]
# ####**d.**
#
# ![taller23-5-1.png](data:image/png;base64,...)

# %% [markdown]
# $$ \begin{array}{l}
# x_{10}( t) =\sum _{k=-\infty }^{\infty } a_{k} \cdot e^{jk10000\pi t}\\
# \\
# a_{k} =\frac{3}{2j\pi k} \cdotp \left( 2e^{-jk\frac{3\pi }{2} t} -e^{-jk\frac{\pi }{2} t} -e^{-jk\frac{5\pi }{2} t}\right)\\
# \\
# X_{10}( j\omega ) =\sum _{k=-\infty }^{\infty } 2\pi \cdot a_{k} \cdot \delta ( \omega -k10000\pi )
# \end{array}$$

# %% [markdown]
# ###**6.** Hallar la ecuación y realizar la gráfica (indicando amplitudes y tiempos relevantes) de la transformada inversa de Fourier de las siguientes señales:

# %% [markdown]
# ####**a.**
#
# ![taller23-6-1.png](data:image/png;base64,...)

# %% [markdown]
# $$x_{10}( t) =4\cos( 10\pi \cdot t)$$

# %%
import matplotlib.pyplot as plt
import numpy as np

# Vector tiempo
t = np.linspace(-1,1,1000)

# Calculo de señal
sig = []
for x in t:
    sig.append(4*np.cos(10*np.pi*x))

# Gráfica de la señal
plt.plot(t, sig)
plt.xlabel(r'$t$')
plt.ylabel(r'$x_{10}(t)$')
plt.title(r'$x_{10}(t)$')
plt.grid(True)
plt.show()

# %% [markdown]
# ####**b.**
#
# ![taller23-6-2.png](data:image/png;base64,...)

# %% [markdown]
# $$x_{11}( t) =2\sin( 20\pi \cdot t)$$

# %%
import matplotlib.pyplot as plt
import numpy as np

# Vector tiempo
t = np.linspace(-0.2,0.2,1000)

# Calculo de señal
sig = []
for x in t:
    sig.append(2*np.sin(20*np.pi*x))

# Gráfica de la señal
plt.plot(t, sig)
plt.xlabel(r'$t$')
plt.ylabel(r'$x_{11}(t)$')
plt.title(r'$x_{11}(t)$')
plt.grid(True)
plt.show()

# %% [markdown]
# ####**c.**
#
# ![taller23-6-3.png](data:image/png;base64,...)

# %% [markdown]
# $$x_{12}( t) =2+3\cos( 10\cdot t)$$

# %%
import matplotlib.pyplot as plt
import numpy as np

# Vector tiempo
t = np.linspace(-2,2,1000)

# Calculo de señal
sig = []
for x in t:
    sig.append(2+3*np.cos(10*x))

# Gráfica de la señal
plt.plot(t, sig)
plt.xlabel(r'$t$')
plt.ylabel(r'$x_{12}(t)$')
plt.title(r'$x_{12}(t)$')
plt.grid(True)
plt.show()

# %% [markdown]
# ####**d.**
#
# ![taller23-6-4.png](data:image/png;base64,...)

# %% [markdown]
# $$x_{13}( t) =1-6\sin( 5\pi \cdot t)$$

# %%
import matplotlib.pyplot as plt
import numpy as np

# Vector tiempo
t = np.linspace(-2,2,1000)

# Calculo de señal
sig = []
for x in t:
    sig.append(1-6*np.sin(5*np.pi*x))

# Gráfica de la señal
plt.plot(t, sig)
plt.xlabel(r'$t$')
plt.ylabel(r'$x_{13}(t)$')
plt.title(r'$x_{13}(t)$')
plt.grid(True)
plt.show()

# %% [markdown]
# ####**e.**
#
# ![taller23-6-5.png](data:image/png;base64,...)

# %% [markdown]
# $$x_{14}( t) =1-\cos( 6\pi \cdot t)$$

# %%
import matplotlib.pyplot as plt
import numpy as np

# Vector tiempo
t = np.linspace(-2,2,1000)

# Calculo de señal
sig = []
for x in t:
    sig.append(1-np.cos(6*np.pi*x))

# Gráfica de la señal
plt.plot(t, sig)
plt.xlabel(r'$t$')
plt.ylabel(r'$x_{14}(t)$')
plt.title(r'$x_{14}(t)$')
plt.grid(True)
plt.show()

# %% [markdown]
# ###**8.** Calcular la energía de las siguientes señales:

# %% [markdown]
# ####**a.** $$x_{13}( t) =20\cdot sinc( 10t)$$

# %% [markdown]
# $$ \begin{array}{l}
# X_{13}( j\omega ) =2\pi \cdot [ u( \omega +10) -u( \omega -10)]\\
# \\
# E\{x_{13}( t)\} =\frac{1}{2\pi } \cdot 20\cdot 4\pi ^{2} =40\pi
# \end{array}$$

# %% [markdown]
# ####**b.** $$x_{14}( t) =20\cdot sinc( 5t)$$

# %% [markdown]
# $$ \begin{array}{l}
# X_{14}( j\omega ) =4\pi \cdot [ u( \omega +5) -u( \omega -5)]\\
# \\
# E\{x_{14}( t)\} =\frac{1}{2\pi } \cdot 10\cdot 16\pi ^{2} =80\pi
# \end{array}$$

# %% [markdown]
# ####**c.**
#
# ![taller23-8-1.png](data:image/png;base64,...)

# %% [markdown]
# $$ \begin{array}{l}
# x_{15}( t) =4\cdot sinc( 2t)\\
# \\
# X_{15}( j\omega ) =2\pi \cdot [ u( \omega +2) -u( \omega -2)]\\
# \\
# E\{x_{15}( t)\} =\frac{1}{2\pi } \cdot 4\cdot 4\pi ^{2} =8\pi
# \end{array}$$

# %% [markdown]
# ####**d.**
#
# ![taller23-8-2.png](data:image/png;base64,...)

# %% [markdown]
# $$ \begin{array}{l}
# x_{16}( t) =sinc\left(\frac{\pi }{4} t\right)\\
# \\
# X_{16}( j\omega ) =\frac{2}{\pi } \cdot 2\pi \cdot \left[ u\left( \omega +\frac{\pi }{4}\right) -u\left( \omega -\frac{\pi }{4}\right)\right]\\
# \\
# E\{x_{16}( t)\} =\frac{1}{2\pi } \cdot \frac{\pi }{2} \cdot 16=4
# \end{array}$$

# %% [markdown]
# ####**g.** $$x_{18}( t) =10sinc( 2t) *\cos( t)$$

# %% [markdown]
# $$ \begin{array}{l}
# X_{18}( j\omega ) =\frac{5}{2} \cdot 2\pi \cdot [ u( \omega +2) -u( \omega -2)] \cdot \pi [ \delta ( \omega +1) +\delta ( \omega -1)]\\
# \\
# X_{18}( j\omega ) =5 \pi ^{2} \cdot [ \delta ( \omega +1) +\delta ( \omega -1)]\\
# \\
# E\{x_{18}( t)\} =\frac{1}{2\pi } \cdot 2\cdot 25\pi ^{4} =25\pi ^{3}
# \end{array}$$

# %% [markdown]
# ###**9.** Graficar la magnitud y la fase (en dos figuras diferentes) de la transformada de Fourier (indicando amplitudes y frecuencias relevantes) de las siguientes señales:

# %% [markdown]
# ####**a.** $$x_{21}( t) =\pi \delta ( t+4)$$

# %% [markdown]
# $$X_{21}( j\omega ) =\pi \cdot e^{j\omega 4}$$

# %% [markdown]
# ####**b.** $$x_{22}( t) =\cos\left( 2\pi \cdot 5000\ Hz\cdot t-\frac{\pi }{4}\right)$$

# %% [markdown]
# $$X_{22}( j\omega ) =\pi \cdot [ \delta ( \omega +10000\pi ) +\delta ( \omega -10000\pi )] \cdot e^{-j\omega \frac{\pi }{4}}$$

# %% [markdown]
# ####**c.** $$x_{23}( t) =4[ u( t) -u( t-10)]$$

# %% [markdown]
# $$X_{23}( j\omega ) =4\cdot 2\cdot 5\cdot sinc( 5\cdot \omega ) \cdot e^{-j\omega 5} =40\cdot sinc( 5\cdot \omega ) \cdot e^{-j\omega 5}$$

# %% [markdown]
# ***Juan Sebastián Bravo Santacruz***
#
# ***Jairo Alberto Hurtado Londoño***
#
# Bogotá, 2021
#
# ![tiara_javeriana.png](data:image/png;base64,...)
