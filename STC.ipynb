# %% [markdown]
# <a href="https://colab.research.google.com/github/SebastianBravo/Solucion_STC/blob/main/STC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Solución Talleres Señales de tiempo continuo**

# %% [markdown]
# ##**Taller No. 01** Definición y clasificación de señales: por dominio, rango, soporte y cota.

# %% [markdown]
# ###**1.** Las señales pueden clasificarse en continuas y discretas (según su dominio) y así mismo tomar valores continuos o discretos (según su rango). Clasifique las siguientes señales según su dominio y su rango:

# %% [markdown]
# ####**a.** $f:R\rightarrow R$

# %% [markdown]
# **Dominio:** Señal continua.
#
# **Rango:** Señal continua.

# %% [markdown]
# ####**b.** $g:Z\rightarrow C$

# %% [markdown]
# **Dominio:** Señal discreta.
#
# **Rango:** Señal continua.

# %% [markdown]
# ####**c.** $h:N\rightarrow Z$

# %% [markdown]
# **Dominio:** Señal discreta.
#
# **Rango:** Señal discreta.

# %% [markdown]
# ###**2.** Hallar el soporte y la cota (si la tienen) de las siguientes señales:

# %% [markdown]
# ####**a.** $n(t) = 3 - |t|$

# %% [markdown]
# **Soporte:** $(-\infty, \infty)$
#
# **Cota:** No posee

# %%
import matplotlib.pyplot as plt
import numpy as np

# Probar distintos valores de tiempo inicial y final
# ¿Cómo cambia el valor máximo de la señal?
t_inicial = -10
t_final = 10
puntos = 10000

# Vector tiempo
t = np.linspace(t_inicial,t_final,puntos)

# Evalua cada tiempo en la señal
n = [3 - abs(x) for x in t]

# Calcula el valor absoluto de la señal
n_abs = [abs(x) for x in n]

# Calcula el valor máximo del valor absoluto de la señal
print(f"El valor máximo de n es {max(n_abs)}")

# Gráfica de la señal
plt.plot(t,n)
plt.xlabel('t')
plt.ylabel('n(t)')
plt.title('Señal n(t)')
plt.grid(True)
plt.show()

# Gráfica del valor absoluto de la señal
plt.plot(t,n_abs)
plt.xlabel('t')
plt.ylabel('|n(t)|')
plt.title('Señal |n(t)|')
plt.grid(True)
plt.show()
# Out:
# El valor máximo de n es 7.0

# %% [markdown]
# ####**c.** $f(t)=log(2t)$

# %% [markdown]
# **Soporte:** $(0, \infty)$
#
# **Cota:** No posee

# %%
import matplotlib.pyplot as plt
import numpy as np

# Probar distintos valores de tiempo inicial y final
# ¿Cómo cambia el valor máximo de la señal? 
t_inicial = 0.1
t_final = 10
puntos = 10000

# Vector tiempo
t = np.linspace(t_inicial,t_final,puntos)

# Evalua cada tiempo en la señal
f = [np.log10(x) for x in t]

# Calcula el valor absoluto de la señal
f_abs = [abs(x) for x in f]

# Calcula el valor máximo del valor absoluto de la señal
print(f"El valor máximo de f es {max(f_abs)}")

# Gráfica de la señal
plt.plot(t,f)
plt.xlabel('t')
plt.ylabel('f(t)')
plt.title('Señal f(t)')
plt.grid(True)
plt.show()

# Gráfica del valor absoluto de la señal
plt.plot(t,f_abs)
plt.xlabel('t')
plt.ylabel('|f(t)|')
plt.title('Señal |f(t)|')
plt.grid(True)
plt.show()
# Out:
# El valor máximo de f es 1.0

# %% [markdown]
# ####**d.** $g(t) =
# \begin{cases}
#   0 & \text{$t<0$} \\
#   e^{-2t} & \text{$t\geq0$}
# \end{cases}$

# %% [markdown]
# **Soporte:** $[0, \infty)$
#
# **Cota:** 1

# %%
import matplotlib.pyplot as plt
import numpy as np

# Probar distintos valores de tiempo inicial y final
# ¿Cómo cambia el valor máximo de la señal?
t_inicial = -3
t_final = 8
puntos = 10000

# Vector tiempo
t = np.linspace(t_inicial,t_final,puntos)

# Evalua cada tiempo en la Señal
g = []

for x in t:
  if x < 0:
    g.append(0)
  else:
    g.append(np.exp(-2*x))

# Calcula el valor absoluto de la Señal
g_abs = [abs(x) for x in g]

# Calcula el valor máximo del valor absoluto de la Señal
print(f"El valor máximo de g es {max(g_abs)}")

# Gráfica de la Señal
plt.plot(t,g)
plt.xlabel('t')
plt.ylabel('g(t)')
plt.title('Señal g(t)')
plt.grid(True)
plt.show()

# Gráfica del valor absoluto de la Señal
plt.plot(t,g_abs)
plt.xlabel('t')
plt.ylabel('|g(t)|')
plt.title('Señal |g(t)|')
plt.grid(True)
plt.show()
# Out:
# El valor máximo de g es 1.0

# %% [markdown]
# ####**f.** $w(t)=
# \begin{cases}
#   -2t & \text{$1<|t|<3$} \\
#   0 & \text{En el resto}
# \end{cases}$

# %% [markdown]
# **Soporte:** $(-3,3)$
#
# **Cota:** *6*

# %%
import matplotlib.pyplot as plt
import numpy as np

# Probar distintos valores de tiempo inicial y final
# ¿Cómo cambia el valor máximo de la señal?
t_inicial = -4
t_final = 4
puntos = 10000

# Vector tiempo
t = np.linspace(t_inicial,t_final,puntos)

# Evalua cada tiempo en la Señal
w = []

for x in t:
  if (abs(x)<3) and (abs(x)>1):
    w.append(-2*x)
  else:
    w.append(0)

# Calcula el valor absoluto de la Señal
w_abs = [abs(x) for x in w]

# Calcula el valor máximo del valor absoluto de la Señal
print(f"El valor máximo de w es {max(w_abs)}")

# Gráfica de la Señal
plt.plot(t,w)
plt.xlabel('t')
plt.ylabel('w(t)')
plt.title('Señal w(t)')
plt.grid(True)
plt.show()

# Gráfica del valor absoluto de la Señal
plt.plot(t,w_abs)
plt.xlabel('t')
plt.ylabel('|w(t)|')
plt.title('Señal |w(t)|')
plt.grid(True)
plt.show()
# Out:
# El valor máximo de w es 5.999799979998

# %% [markdown]
# ##**Taller No. 02** Transformación de la variable independiente: inversión - funciones pares e impares.

# %% [markdown]
# ###**1.** Indicar la validez (V o F) de las siguientes afirmaciones:

# %% [markdown]
# ####**a.** Función PAR + Función PAR = Función PAR

# %% [markdown]
# Verdadero

# %% [markdown]
# ####**b.** Función IMPAR + Función PAR = Función PAR

# %% [markdown]
# Falso

# %% [markdown]
# ####**c.** Función IMPAR + Función IMPAR = Función IMPAR

# %% [markdown]
# Verdadero

# %% [markdown]
# ####**d.** Función IMPAR + Función PAR = Función IMPAR

# %% [markdown]
# Falso

# %% [markdown]
# ###**2.** Graficar la parte par e impar de las siguientes funciones:

# %% [markdown]
# ####**a.** $a(t) =
# \begin{cases}
#   t & \text{$|t|<4$} \\
#   0 & \text{$|t|\geq4$}
# \end{cases}$

# %%
import matplotlib.pyplot as plt
import numpy as np

# Vector tiempo
t = np.linspace(-6,6,1000)
a = []
a_par = []
a_impar =[]

# Evalua cada tiempo en la señal
for x in t:
  if (abs(x)<4):
    a.append(x)
  else:
    a.append(0)

# Invierte la señal en tiempo
a_inv = list(reversed(a))

# Calcula la parte par e impar de la señal
for i in range(len(a)):
  a_par.append((a[i] + a_inv[i])/2)
  a_impar.append((a[i] - a_inv[i])/2)

# Gráfica de la señal
plt.plot(t,a)
plt.xlabel('t')
plt.ylabel('a(t)')
plt.title('Señal a(t)')
plt.grid(True)
plt.show()

# Gráfica de la componente par de la señal
plt.plot(t,a_par, label='Parte par')
plt.xlabel('t')
plt.title('Componente par de a(t)')
plt.ylim(-4, 4)  
plt.grid(True)
plt.show()

# Gráfica de la componente impar de la señal
plt.plot(t,a_impar, label='Parte impar')
plt.xlabel('t')
plt.title('Componente impar de a(t)')
plt.grid(True)
plt.show()

# %% [markdown]
# ####**b.**
# ![taller2-2-b.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Vector tiempo
t = np.linspace(-6,6,1000)
b = []
b_par = []
b_impar =[]

# Evalua cada tiempo en la señal
for x in t:
  if (x <= 4) and (x >= 0):
    b.append(-x + 4)
  else:
    b.append(0)

# Invierte la señal en tiempo
b_inv = list(reversed(b))

# Calcula la parte par e impar de la señal
for i in range(len(b)):
  b_par.append((b[i] + b_inv[i])/2)
  b_impar.append((b[i] - b_inv[i])/2)

# Gráfica de la señal
plt.plot(t,b)
plt.xlabel('t')
plt.ylabel('b(t)')
plt.title('Señal b(t)')
plt.grid(True)
plt.show()

# Gráfica de la componente par de la señal
plt.plot(t,b_par, label='Parte par')
plt.xlabel('t')
plt.title('Componente par de b(t)')
plt.grid(True)
plt.show()

# Gráfica de la componente impar de la señal
plt.plot(t,b_impar, label='Parte impar')
plt.xlabel('t')
plt.title('Componente impar de b(t)')
plt.grid(True)
plt.show()

# %% [markdown]
# ####**c.** $a(t) = u(t)$

# %%
import matplotlib.pyplot as plt
import numpy as np

# Vector tiempo
t = np.linspace(-6,6,1000)
c = []
c_par = []
c_impar =[]

# Evalua cada tiempo en la señal
for x in t:
  if (x >= 0):
    c.append(1)
  else:
    c.append(0)

# Invierte la señal en tiempo
c_inv = list(reversed(c))

# Calcula la parte par e impar de la señal
for i in range(len(c)):
  c_par.append((c[i] + c_inv[i])/2)
  c_impar.append((c[i] - c_inv[i])/2)

# Gráfica de la señal
plt.plot(t,c)
plt.xlabel('t')
plt.ylabel('c(t)')
plt.title('Función c(t)')
plt.grid(True)
plt.show()

# Gráfica de la componente par de la señal
plt.plot(t,c_par, label='Parte par')
plt.xlabel('t')
plt.title('Componente par de c(t)')
plt.grid(True)
plt.show()

# Gráfica de la componente impar de la señal
plt.plot(t,c_impar, label='Parte impar')
plt.xlabel('t')
plt.title('Componente impar de c(t)')
plt.ylim(-0.6, 0.6)
plt.grid(True)
plt.show()

# %% [markdown]
# ##**Taller No. 03** Señales especiales. Función paso y señal impulso.

# %% [markdown]
# ###**1.** Graficar las siguientes señales. Indique tiempos y amplitudes relevantes:

# %% [markdown]
# ####**a.** $2u(t)$

# %%
import matplotlib.pyplot as plt
import numpy as np

# Vector tiempo
t = np.linspace(-6,6,1000)

def u(t, a, b, t0, c):
  """
  Función que crea señal au(bt + t0) + c 
  Toma como parametros un vector de tiempo(t) y a, b, t0 y c
  Retorna una pareja de tiempo y amplitud
  """
  amp = []
  
  # Crea funcion u(t)
  for x in t:
    if x >= 0:
      amp.append(1)
    else:
      amp.append(0)

  # Desplazamiento y escalado en tiempo
  t = [(x+t0)/b for x in t]

  # Desplazamiento en eje vertical y escalado en amplitud
  amp = [(i*a)+c for i in amp]

  return (t, amp)

# Define la señal
t, sig = u(t, 2, 1, 0, 0)

# Gráfica de la señal
plt.plot(t,sig)
plt.xlabel('t')
plt.ylabel(r'$2u(t)$')
plt.title(r'Señal $2u(t)$')
plt.grid(True)
plt.show()

# %% [markdown]
# ####**b.** $4u(t-3)$

# %%
import matplotlib.pyplot as plt
import numpy as np

# Vector tiempo
t = np.linspace(-6,6,1000)

def u(t, a, b, t0, c):
  """
  Función que crea señal au(bt + t0) + c 
  Toma como parametros un vector de tiempo(t) y a, b, t0 y c
  Retorna una pareja de tiempo y amplitud
  """
  amp = []
  
  # Crea funcion u(t)
  for x in t:
    if x >= 0:
      amp.append(1)
    else:
      amp.append(0)

  # Desplazamiento y escalado en tiempo
  t = [(x+t0)/b for x in t]

  # Desplazamiento en eje vertical y escalado en amplitud
  amp = [(i*a)+c for i in amp]

  return (t, amp)

# Define la señal
t, sig = u(t, 4, 1, 3, 0)

# Gráfica de la señal
plt.plot(t,sig)
plt.xlabel('t')
plt.ylabel(r'$4u(t-3)$')
plt.title(r'Señal $4u(t-3)$')
plt.grid(True)
plt.show()

# %% [markdown]
# ####**c.** $-u(t+5)$

# %%
import matplotlib.pyplot as plt
import numpy as np

# Vector tiempo
t = np.linspace(-6,6,1000)

def u(t, a, b, t0, c):
  """
  Función que crea señal au(bt + t0) + c 
  Toma como parametros un vector de tiempo(t) y a, b, t0 y c
  Retorna una pareja de tiempo y amplitud
  """
  amp = []
  
  # Crea funcion u(t)
  for x in t:
    if x >= 0:
      amp.append(1)
    else:
      amp.append(0)

  # Desplazamiento y escalado en tiempo
  t = [(x+t0)/b for x in t]

  # Desplazamiento en eje vertical y escalado en amplitud
  amp = [(i*a)+c for i in amp]

  return (t, amp)

# Define la señal
t, sig = u(t, -1, 1, -5, 0)

# Gráfica de la señal
plt.plot(t,sig)
plt.xlabel('t')
plt.ylabel(r'$-u(t+5)$')
plt.title(r'Señal $-u(t+5)$')
plt.grid(True)
plt.show()

# %% [markdown]
# ###**2.** Indicar la expresión correspondiente (en términos de la función paso) de las siguientes señales:

# %% [markdown]
# ####**a.**
# ![taller3-2-a.png](data:image/png;base64,...)

# %% [markdown]
# $u(-t+3)$

# %% [markdown]
# ####**b.**
# ![taller3-2-b.png](data:image/png;base64,...)

# %% [markdown]
# $u(t+2)$

# %% [markdown]
# ####**c.**
# ![taller3-2-c.png](data:image/png;base64,...)

# %% [markdown]
# $-u(t+4)$

# %% [markdown]
# ###**3.** Graficar las siguientes señales. Indique tiempos y amplitudes relevantes:

# %% [markdown]
# ####**a.** $u(𝑡+1)−u(𝑡−2)$

# %%
import matplotlib.pyplot as plt
import numpy as np

# Vector tiempo
t = np.linspace(-4,4,1000)

# Calculo de señal
sig = []
for x in t:
  if (x>=-1) and (x<=2):
    sig.append(1)
  else:
    sig.append(0)

# Gráfica de la señal
plt.plot(t, sig)
plt.xlabel('t')
plt.ylabel(r'$u(𝑡+1)−u(𝑡−2)$')
plt.title(r'Señal $u(𝑡+1)−u(𝑡−2)$')
plt.grid(True)
plt.show()

# %% [markdown]
# ####**b.** $4u(-𝑡+5)+4u(𝑡−8)$

# %%
import matplotlib.pyplot as plt
import numpy as np

# Vector tiempo
t = np.linspace(3,10,1000)

# Calculo de señal
sig = []
for x in t:
  if (x>=5) and (x<=8):
    sig.append(0)
  else:
    sig.append(4)

# Gráfica de la señal
plt.plot(t, sig)
plt.xlabel('t')
plt.ylabel(r'$4u(-𝑡+5)+4u(𝑡−8)$')
plt.title(r'Señal $4u(-𝑡+5)+4u(𝑡−8)$')
plt.grid(True)
plt.show()

# %% [markdown]
# ###**4.** Indicar la expresión correspondiente (en términos de la función paso) de las siguientes señales:

# %% [markdown]
# ####**a.**
#  ![taller3-4-a.png](data:image/png;base64,...)

# %% [markdown]
# **Opción 1:** $2u(t+2) - 2u(t-3)$
# **Opción 2:** $2\cdot u(t+2) \cdot u(-t+3)$

# %% [markdown]
# ###**5.** Graficar las siguientes señales. Indique tiempos y amplitudes relevantes:

# %% [markdown]
# ####**a.** $\delta (t-2)$

# %%
import matplotlib.pyplot as plt
import numpy as np

# Vector tiempo
t = np.linspace(-2,2,1000000)

def dirac_delta(t, a, b, t0, c):
  """
  Función que crea señal au(bt + t0) + c 
  Toma como parametros un vector de tiempo(t) y a, b, t0 y c
  Retorna una pareja de tiempo y amplitud
  """
  # Entre más pequeño sea delta, mejor es la representación del impulso
  delta = 1/1000
  amp = []
  
  # Crea funcion dirac_delta(t)
  for x in t:
    if (x >= -delta/2) and (x <= delta/2):
      amp.append(1/delta)
    else:
      amp.append(0)

  # Desplazamiento y escalado en tiempo
  t = [(x+t0)/b for x in t]

  # Desplazamiento en eje vertical y escalado en amplitud
  amp = [(i*a)+c for i in amp]

  return (t, amp)

def integral(t, amp):
  """
  Función que calcula la integral de una señal
  Toma como parametros una pareja de (tiempo, amplitud)
  Retorna el resultado de la integral
  """
  dt = (max(t)- min(t))/len(t)
  area = 0

  for a in amp:
    area += dt*a

  return area

# Define la señal
t, sig = dirac_delta(t, 1, 1, 2, 0)

# Imprime el area bajo la curva de la señal
print(f"El área bajo la curva de la señal es: {integral(t, sig)}")

# Gráfica de la señal
plt.plot(t,sig)
plt.xlabel('t')
plt.ylabel(r'$\delta (t-2)$')
plt.title(r'Señal $\delta (t-2)$')
plt.grid(True)
plt.show()
# Out:
# El área bajo la curva de la señal es: 1.0000000000000007

# %% [markdown]
# ####**b.** $-\delta (t+2)$

# %%
import matplotlib.pyplot as plt
import numpy as np

# Vector tiempo
t = np.linspace(-2,2,1000000)

def dirac_delta(t, a, b, t0, c):
  """
  Función que crea señal au(bt + t0) + c 
  Toma como parametros un vector de tiempo(t) y a, b, t0 y c
  Retorna una pareja de tiempo y amplitud
  """
  # Entre más pequeño sea delta, mejor es la representación del impulso
  delta = 1/1000
  amp = []
  
  # Crea funcion dirac_delta(t)
  for x in t:
    if (x >= -delta/2) and (x <= delta/2):
      amp.append(1/delta)
    else:
      amp.append(0)

  # Desplazamiento y escalado en tiempo
  t = [(x+t0)/b for x in t]

  # Desplazamiento en eje vertical y escalado en amplitud
  amp = [(i*a)+c for i in amp]

  return (t, amp)

def integral(t, amp):
  """
  Función que calcula la integral de una señal
  Toma como parametros una pareja de (tiempo, amplitud)
  Retorna el resultado de la integral
  """
  dt = (max(t)- min(t))/len(t)
  area = 0

  for a in amp:
    area += dt*a

  return area

# Define la señal
t, sig = dirac_delta(t, -1, 1, -2, 0)

# Imprime el area bajo la curva de la señal
print(f"El área bajo la curva de la señal es: {integral(t, sig)}")

# Gráfica de la señal
plt.plot(t,sig)
plt.xlabel('t')
plt.ylabel(r'$-\delta (t+2)$')
plt.title(r'Señal $-\delta (t+2)$')
plt.grid(True)
plt.show()
# Out:
# El área bajo la curva de la señal es: -1.0000000000000007

# %% [markdown]
# ####**c.** $2\delta (-t)$

# %%
import matplotlib.pyplot as plt
import numpy as np

# Vector tiempo
t = np.linspace(-2,2,1000000)

def dirac_delta(t, a, b, t0, c):
  """
  Función que crea señal au(bt + t0) + c 
  Toma como parametros un vector de tiempo(t) y a, b, t0 y c
  Retorna una pareja de tiempo y amplitud
  """
  # Entre más pequeño sea delta, mejor es la representación del impulso
  delta = 1/1000
  amp = []
  
  # Crea funcion dirac_delta(t)
  for x in t:
    if (x >= -delta/2) and (x <= delta/2):
      amp.append(1/delta)
    else:
      amp.append(0)

  # Desplazamiento y escalado en tiempo
  t = [(x+t0)/b for x in t]

  # Desplazamiento en eje vertical y escalado en amplitud
  amp = [(i*a)+c for i in amp]

  return (t, amp)

def integral(t, amp):
  """
  Función que calcula la integral de una señal
  Toma como parametros una pareja de (tiempo, amplitud)
  Retorna el resultado de la integral
  """
  dt = (max(t)- min(t))/len(t)
  area = 0

  for a in amp:
    area += dt*a

  return area

# Define la señal
t, sig = dirac_delta(t, 2, -1, 0, 0)

# Imprime el area bajo la curva de la señal
print(f"El área bajo la curva de la señal es: {integral(t, sig)}")

# Gráfica de la señal
plt.plot(t,sig)
plt.xlabel('t')
plt.ylabel(r'$2\delta (-t)$')
plt.title(r'Señal $2\delta (-t)$')
plt.grid(True)
plt.show()
# Out:
# El área bajo la curva de la señal es: 2.0000000000000013
