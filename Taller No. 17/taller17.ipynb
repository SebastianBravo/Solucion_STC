# %% [markdown]
# ##**Taller No. 17** Propiedades de los sistemas.

# %% [markdown]
# ###**1.** A continuación, se muestra la relación entrada-salida de varios sistemas. Indicar si son **sistemas con o sin memoria**.

# %% [markdown]
# ####**a.** $$y_{a}( t) \ =\ \int _{-\infty }^{t} x_{a}( \tau ) d\tau $$

# %% [markdown]
# Sistema con memoria

# %% [markdown]
# ####**c.** $$y_{c}( t) \ =\ [ x_{c}( t)]^{2} \cdotp u( t)$$

# %% [markdown]
# Sistema sin memoria

# %% [markdown]
# ####**e.** $$y_{e}( t) =x_{e}( t) \cdotp e^{2t} \cdotp u( -t+1)$$

# %% [markdown]
# Sistema con memoria

# %% [markdown]
# ####**g.** $$y_{g}( t) \ =\ x_{g}( t) \cdotp [ u( t+2) -u( t-2)]$$

# %% [markdown]
# Sistema con memoria

# %% [markdown]
# ####**i.** $$y_{i}( t) \ =\ 2\cdotp x_{i}( t) \cdotp \delta ( t-1)$$

# %% [markdown]
# Sistema con memoria

# %% [markdown]
# ####**k.** $$y_{k}( t) =x_{k}( t+1) \cdotp \delta ( t-1)$$

# %% [markdown]
# Sistema con memoria

# %% [markdown]
# ####**m.** $$y_{m}( t) =x_{m}( 2t)$$

# %% [markdown]
# Sistema sin memoria

# %% [markdown]
# ###**2.** A continuación, se muestra la relación entrada-salida de varios sistemas. Indicar si son **sistemas con o sin memoria**.

# %% [markdown]
# ####**a.** $$y( t) \ =\ \int _{-\infty }^{t} x( \tau ) d\tau $$

# %% [markdown]
# Sistema con memoria

# %% [markdown]
# ####**b.** $$y( t) \ =\ x( t) \cdotp x( t-t_{0})$$

# %% [markdown]
# Sistema con memoria

# %% [markdown]
# ####**c.** $$y( t) \ =\ x( t) -0.5x( t-t_{0})$$

# %% [markdown]
# Sistema con memoria

# %% [markdown]
# ####**d.** $$y( t) \ =[ x( t) +3]^{2}$$

# %% [markdown]
# Sistema sin memoria

# %% [markdown]
# ####**e.** $$y( t) =par\{x( t)\}$$

# %% [markdown]
# Sistema con memoria

# %% [markdown]
# ####**f.** $$y( t) \ =x( 2t)$$

# %% [markdown]
# Sistema sin memoria

# %% [markdown]
# ###**3.** A continuación, se muestra la relación entrada-salida de varios sistemas. Indicar si son **sistemas causales (NO anticipativos) o NO causales (anticipativos).**

# %% [markdown]
# ####**a.** $$y( t) \ =\ \int _{-\infty }^{t} x( \tau ) d\tau $$

# %% [markdown]
# Sistema causal

# %% [markdown]
# ####**b.** $$y( t) \ =\ x( t) \cdotp x( t-t_{0})$$

# %% [markdown]
# Sistema causal

# %% [markdown]
# ####**c.** $$y( t) \ =\ x( t) -0.5x( t-t_{0})$$

# %% [markdown]
# Sistema causal

# %% [markdown]
# ####**d.** $$y( t) \ =[ x( t) +3]^{2}$$

# %% [markdown]
# Sistema causal

# %% [markdown]
# ####**e.** $$y( t) =par\{x( t)\}$$

# %% [markdown]
# Sistema no causal

# %% [markdown]
# ####**f.** $$y( t) \ =x( 2t)$$

# %% [markdown]
# Sistema no causal

# %% [markdown]
# ###**4.** A continuación, se muestra la relación entrada-salida de varios sistemas. Indicar si son **sistemas estables o no estables.**

# %% [markdown]
# ####**a.** $$y( t) \ =\ \int _{-\infty }^{t} x( \tau ) d\tau $$

# %% [markdown]
# Sistema estable

# %% [markdown]
# ####**b.** $$y( t) \ =\ x( t) \cdotp x( t-t_{0})$$

# %% [markdown]
# Sistema estable

# %% [markdown]
# ####**c.** $$y( t) \ =\ \log\{|x( t) |\} \cdotp u( t-2)$$

# %% [markdown]
# Sistema no estable

# %% [markdown]
# ####**d.** $$y( t) \ =e^{x( t)}$$

# %% [markdown]
# Sistema estable

# %% [markdown]
# ####**e.** $$y( t) =par\{x( t)\}$$

# %% [markdown]
# Sistema estable

# %% [markdown]
# ####**f.** $$y( t) \ =x( 2t)$$

# %% [markdown]
# Sistema estable

# %% [markdown]
# ###**5.** A continuación, se muestra la relación entrada salida de varios sistemas. Indicar si son **sistemas invertibles o no invertibles.** Si son invertibles, hallar el sistema inverso.

# %% [markdown]
# ####**a.** $$y( t) \ =\ \int _{0 }^{10} x( \tau ) d\tau $$

# %% [markdown]
# Sistema no invertible

# %% [markdown]
# ####**b.** $$y( t) \ =\ x( t) \cdotp x( t-t_{0})$$

# %% [markdown]
# Sistema no invertible

# %% [markdown]
# ####**c.** $$y( t) \ =\ x( t) + x( t-t_{0})$$

# %% [markdown]
# Sistema no invertible

# %% [markdown]
# ####**d.** $$y( t) \ =e^{x( t)}$$

# %% [markdown]
# Sistema invertible
#
# $$x( t) \ =\ \ln( y( t))$$

# %% [markdown]
# ####**e.** $$y( t) =par\{x( t)\}$$

# %% [markdown]
# Sistema no invertible

# %% [markdown]
# ####**f.** $$y( t) \ =x( 2t)$$

# %% [markdown]
# Sistema invertible
#
# $$x( t) \ =\ y\left(\frac{t}{2}\right)$$

# %% [markdown]
# ###**6.** A continuación, se muestra la relación entrada-salida de varios sistemas. Indicar si son **sistemas aditivos o no aditivos.**

# %% [markdown]
# ####**a.** $$y( t) \ =\ \int _{-\infty }^{t} x( \tau ) d\tau $$

# %% [markdown]
# Sistema aditivo

# %% [markdown]
# ####**b.** $$y( t) \ =\ x( t) \cdotp x( t-t_{0})$$

# %% [markdown]
# Sistema no aditivo

# %% [markdown]
# ####**c.** $$y( t) =|x( t) |$$

# %% [markdown]
# Sistema no aditivo

# %% [markdown]
# ####**d.** $$y( t) \ =e^{x( t)}$$

# %% [markdown]
# Sistema no aditivo

# %% [markdown]
# ####**e.** $$y( t) =par\{x( t)\}$$

# %% [markdown]
# Sistema aditivo

# %% [markdown]
# ####**f.** $$y( t) \ =x( 2t)$$

# %% [markdown]
# Sistema aditivo

# %% [markdown]
# ###**7.** A continuación, se muestra la relación entrada-salida de varios sistemas. Indicar si son **sistemas homogéneos o no homogéneos.**

# %% [markdown]
# ####**a.** $$y( t) \ =\ \int _{-\infty }^{t} x( \tau ) d\tau $$

# %% [markdown]
# Sistema homogéneo

# %% [markdown]
# ####**b.** $$y( t) \ =\ x( t) \cdotp x( t-t_{0})$$

# %% [markdown]
# Sistema no homogéneo

# %% [markdown]
# ####**c.** $$y( t) =|x( t) |$$

# %% [markdown]
# Sistema homogéneo

# %% [markdown]
# ####**d.** $$y( t) \ =e^{x( t)}$$

# %% [markdown]
# Sistema no homogéneo

# %% [markdown]
# ####**e.** $$y( t) =par\{x( t)\}$$

# %% [markdown]
# Sistema homogéneo

# %% [markdown]
# ####**f.** $$y( t) \ =x( 2t)$$

# %% [markdown]
# Sistema homogéneo

# %% [markdown]
# ###**8.** A continuación, se muestra la relación entrada-salida de varios sistemas. Indicar si son **sistemas invariantes con el tiempo o variantes con el tiempo.**

# %% [markdown]
# ####**a.** $$y( t) \ =\ \int _{-\infty }^{t} x( \tau ) d\tau $$

# %% [markdown]
# Sistema variante con el tiempo

# %% [markdown]
# ####**b.** $$y( t) \ =\ x( t) \cdotp x( t-t_{0})$$

# %% [markdown]
# Sistema invariante con el tiempo

# %% [markdown]
# ####**c.** $$y( t) =|x( t) |$$

# %% [markdown]
# Sistema invariante con el tiempo

# %% [markdown]
# ####**d.** $$y( t) \ =e^{x( t)}$$

# %% [markdown]
# Sistema invariante con el tiempo

# %% [markdown]
# ####**e.** $$y( t) =par\{x( t)\}$$

# %% [markdown]
# Sistema invariante con el tiempo

# %% [markdown]
# ####**f.** $$y( t) \ =x( 2t)$$

# %% [markdown]
# Sistema invariante con el tiempo

# %% [markdown]
# ***Juan Sebastián Bravo Santacruz***
#
# ***Jairo Alberto Hurtado Londoño***
#
# Bogotá, 2021
#
# ![tiara_javeriana.png](data:image/png;base64,...)
