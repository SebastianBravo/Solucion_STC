# %% [markdown]
# ##**Taller No. 24** Aplicación de la transformada de Fourier.

# %% [markdown]
# ###**1.** Sea $x(t)$ una señal en tiempo continuo, cuya transformada de Fourier $X(jω)$ se muestra en la siguiente figura. Donde $ω1 = 600π rad/s = 2π · 300 Hz$ y $ω2 = 6 800π rad/s = 2π · 3 400 Hz$
#
# ![taller24-1-1.png](data:image/png;base64,...)
#
# ### Dicha señal pasa por un sistema de transmisión (modulación y filtrado) como el que se muestra en la figura, donde $ωc = 7 400π rad/s = 2π · 3 700 Hz$.
#
# ![taller24-1-2.png](data:image/png;base64,...)

# %% [markdown]
# ####**a.** Grafique el espectro en frecuencia (**Transformada de Fourier**) de la señal en punto 2 $\displaystyle ②=\sin( 2\pi \cdot 3700t)$. Indique las amplitudes y frecuencias relevantes.

# %% [markdown]
# ![taller24-1-4.png](data:image/png;base64,...)

# %% [markdown]
# ####**b.** Grafique el espectro en frecuencia (Transformada de Fourier) de la señal en punto 3 $\displaystyle ③=x( t) \cdot \sin( 2\pi \cdot 3700\ t)$. La cual corresponde a la modulación de la señal $\displaystyle x( t)$ por medio de una señal sinusoidal. Indique las amplitudes y frecuencias relevantes.

# %% [markdown]
# ![taller24-1-5.png](data:image/png;base64,...)

# %% [markdown]
# ###La señal del punto ③, pasa por un SLIT, cuya respuesta en frecuencia - Transformada de Fourier de respuesta impulso $\displaystyle h_{1}( t)$ es decir: $\displaystyle F\{h_{1}( t)\} =H_{1}( j\omega )$.
#
#
#
# ###Con$\displaystyle \ \omega _{1} =2\pi \cdot 300\ Hz=600\pi \ rad/s$ y $\displaystyle \omega _{2} =2\pi \cdot 3\ 400\ Hz=6800\pi \ rad/s$.

# %% [markdown]
# ####**c.** Grafique el espectro en frecuencia (Transformada de Fourier) de la señal en punto ④: $\displaystyle ④=\ [ x( t) \cdot \sin( 2\pi \cdot 3700\ t)] *h_{1}( t)$.
#
#
#
# ###Indique las amplitudes y frecuencias relevantes

# %% [markdown]
# ![taller24-1-6.png](data:image/png;base64,...)

# %% [markdown]
# ### La señal del punto ④, en el sistema de transmisión, es enviada para que sea recuperada por medio de un sistema receptor (demodulación y filtrado) como el que se muestra en la figura
#
# ![taller24-1-3.png](data:image/png;base64,...)
#
# ### La señal del punto ④ (suponga que la señal transmitida corresponde a la misma señal recibida), es multiplicada por la señal sinusoidal del punto ⑤. Esta señal sinusoidal del punto ⑤ en el sistema de recepción, corresponde a la misma señal del sistema de transmisión del punto ②.

# %% [markdown]
# ####**d.** Grafique el espectro en frecuencia (Transformada de Fourier) de la señal en punto ⑥: $\displaystyle ⑥=\{[ x( t) \cdot \sin( 2\pi \cdot 3700\ t)] *h_{1}( t)\} \cdot \sin( 2\pi \cdot 3700\ t) .$
#
# ####La cual corresponde a la demodulación de la señal del punto ④ por medio de una señal sinusoidal. Indique las amplitudes y frecuencias relevantes.

# %% [markdown]
# ![taller24-1-7.png](data:image/png;base64,...)

# %% [markdown]
# ### La señal del punto ⑥, pasa por un SLIT, cuya respuesta en frecuencia (Transformada de Fourier) de respuesta impulso $\displaystyle h_{2} \ ( t)$ es decir:  $\displaystyle F\{h_{2} \ ( t)\} =H_{2} \ ( j\omega )$. Con $\displaystyle \omega _{2} =2\pi \cdot 3\ 400\ Hz=6800\pi \ rad/s$.

# %% [markdown]
# ####**e.** Grafique el espectro en frecuencia (Transformada de Fourier) de la señal en punto ⑦: $\displaystyle ⑦=\{[ x( t) \cdot \sin( 2\pi \cdot 3700\ t)] *h_{1}( t)\} *h_{2}( t) .$
#
# ####Indique las amplitudes y frecuencias relevantes.

# %% [markdown]
# ![taller24-1-8.png](data:image/png;base64,...)

# %% [markdown]
# ####**f.** Hallar el valor de A - amplitud de $\displaystyle H_{2} \ ( j\omega )$ -, para que la señal de salida $\displaystyle y( t)$, sea exactamente igual a la señal de entrada $\displaystyle x( t)$.

# %% [markdown]
# $$A=\frac{10}{-\frac{5}{2}}=-4$$

# %% [markdown]
# ###**2.** Sea $\displaystyle m( t)$ una señal definida como: $\displaystyle m( t) =A_{0} \ sinc( 2\pi f_{0} \cdot t)$ que se muestra en la figura
#
# ![taller24-2-1.png](data:image/png;base64,...)

# %% [markdown]
# ####**a.** A partir de la figura anterior, hallar el valor de $\displaystyle A_{0}$ en la función $\displaystyle m( t)$.

# %% [markdown]
# $$A_0=1, a=2\pi, f_0=1$$

# %% [markdown]
# ### La señal $\displaystyle m( t)$ pasa por el sistema mostrado en la siguiente figura:
#
# ![taller24-2-2.png](data:image/png;base64,...)
#
# ###donde:
# \begin{equation*}
# H( j\omega ) =\begin{cases}
# 1 & 2\pi \cdot 75\ kHz< |\omega |< 2\pi \cdot 125\ kHz\\
# 0 & En\ otro\ caso
# \end{cases}
# \end{equation*}

# %% [markdown]
# ####**b.** Grafique el espectro en frecuencia (Transformada de Fourier) de la señal $\displaystyle \cos( 2\pi \cdot 100kHz\ t)$. Indique las amplitudes y frecuencias relevantes.

# %% [markdown]
# ![taller24-2-3.png](data:image/png;base64,...)

# %% [markdown]
# ####**c.** Grafique el espectro en frecuencia (Transformada de Fourier) de la señal $\displaystyle z( t)$ que corresponde la suma de la señal m(t) y una señal sinusoidal: $\displaystyle z( t) =m( t) +\cos( 2\pi \cdot 100kHz\ t)$. Indique las amplitudes y frecuencias relevantes.

# %% [markdown]
# ![taller24-2-4.png](data:image/png;base64,...)

# %% [markdown]
# ### La señal $\displaystyle z$(t) pasa por un sistema que eleva al cuadrado la señal, dando por resultado: $\displaystyle z^{2}( t)$.

# %% [markdown]
# ####**d.** Grafique el espectro en frecuencia (Transformada de Fourier) de la señal $\displaystyle z^{2}( t)$. Indique las amplitudes y frecuencias relevantes.

# %% [markdown]
# ![taller24-2-5.png](data:image/png;base64,...)

# %% [markdown]
# ### La señal $\displaystyle z^{2}( t)$ pasa por un SLIT, cuya respuesta en frecuencia - Transformada de Fourier de respuesta impulso $\displaystyle h( t)$ es decir: $\displaystyle \ F\{h( t)\} =H( j\omega )$
#
# ### Con:
# \begin{equation*}
# H( j\omega ) =\begin{cases}
# 1 & 2\pi \cdot 75\ kHz< |\omega |< 2\pi \cdot 125\ kHz\\
# 0 & En\ otro\ caso
# \end{cases}
# \end{equation*}

# %% [markdown]
# ####**e.** Grafique el espectro en frecuencia (Transformada de Fourier) de la señal $y(t)$. Indique las amplitudes y frecuencias relevantes.

# %% [markdown]
# ![taller24-2-6.png](data:image/png;base64,...)

# %% [markdown]
# ###**3.** Sea $\displaystyle x( t)$ una señal periódica, con periodo T= 1 ms. Al expresar dicha señal en Series de Fourier se encontró que:
#
#
# \begin{equation*}
# a_{-2} =2,\ a_{-1} =-\frac{1}{j} ,\ a_{0} =5,\ a_{1} =\frac{1}{j} ,\ a_{2} =2
# \end{equation*}
# ###Para el resto de $\displaystyle a_{k}$ se tiene que $\displaystyle a_{k} =0$

# %% [markdown]
# ####**a.** Expresar la función periódica $\displaystyle x( t)$ como combinación lineal de señales sinusoidales.

# %% [markdown]
# $$
# \begin{equation*}
# x( t) =5+4\cos( 2\pi \cdot 2kHz\ t) +2\sin( 2\pi \cdot 1kHz\ t)
# \end{equation*}$$

# %% [markdown]
# ####**b.** Hallar la potencia de la señal $\displaystyle x( t)$.

# %% [markdown]
# $$P\{x( t)\} =25+4+4+1+1=35\ W$$

# %% [markdown]
# ####**c.** Si $\displaystyle x( t)$ es la señal de entrada a un SLIT cuya respuesta impulso está dada por: $\displaystyle h( t) =u( t) \cdot e^{-2t}$. Hallar la señal de salida $\displaystyle y( t)$ del sistema.

# %% [markdown]
# $$ \begin{array}{l}
# H( j\omega ) =\frac{1}{2+j\omega }\\
# \\
# Y( j\omega ) =X( j\omega ) \cdot H( j\omega ) =5\cdot \frac{1}{2} \delta ( t) +\frac{1}{j} \cdot \frac{1}{2+j2000\pi } \delta ( t-2000\pi ) -\frac{1}{j} \cdot \frac{1}{2-j2000\pi } \delta ( t+2000\pi )\\
# +2\cdot \frac{1}{2+j4000\pi } \delta ( t-4000\pi ) +2\cdot \frac{1}{2-j4000\pi } \delta ( t+4000\pi )
# \end{array}$$

# %% [markdown]
# ####**d.** Hallar la potencia de la señal de salida $\displaystyle y( t)$.

# %% [markdown]
# $$P\{y( t)\} =\frac{25}{4} +\left( 1.59\times 10^{-4}\right)^{2} +\left( 1.59\times 10^{-4}\right)^{2} +\left( 1.59\times 10^{-4}\right)^{2} +\left( 1.59\times 10^{-4}\right)^{2} =6.25\ W$$

# %% [markdown]
# ***Juan Sebastián Bravo Santacruz***
#
# ***Jairo Alberto Hurtado Londoño***
#
# Bogotá, 2021
#
# ![tiara_javeriana.png](data:image/png;base64,...)
